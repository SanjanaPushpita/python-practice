# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjanaPushpita/python-practice/blob/main/pre_trained_VGG16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.applications.vgg16 import VGG16
model = VGG16()
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 7s 0us/step

# %%
model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ...

# %%
from keras.preprocessing.image import load_img
from keras.applications.imagenet_utils import preprocess_input
import numpy as np

img = load_img('abc.jpg', target_size=(224, 224))
img = np.array(img)
img = img.reshape(1, 224, 224, 3)
img = preprocess_input(img)

img
from skimage import io
my_img = io.imread('abc.jpg')
io.imshow(my_img)
# Out:
# <ipython-input-10-004d9f0061da>:13: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(my_img)

# %%
yhat = model.predict(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step

# %%
from keras.applications.vgg16 import decode_predictions, preprocess_input
label = decode_predictions(yhat)
label
# Out:
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [[('n02667093', 'abaya', 0.16038509),
#   ('n04325704', 'stole', 0.13423969),
#   ('n04479046', 'trench_coat', 0.12549429),
#   ('n03630383', 'lab_coat', 0.100818075),
#   ('n03877472', 'pajama', 0.09729007)]]

# %%
from keras.preprocessing.image import load_img
from keras.applications.imagenet_utils import preprocess_input
import numpy as np

img2 = load_img('a.jpg', target_size=(224, 224))
img2 = np.array(img2)
img2 = img2.reshape(1, 224, 224, 3)
img2 = preprocess_input(img2)

img2
from skimage import io
my_img2 = io.imread('a.jpg')
io.imshow(my_img2)
# Out:
# <ipython-input-30-1c919706a069>:13: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(my_img2)

# %%
yhat2 = model.predict(img2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step

# %%
from keras.applications.vgg16 import decode_predictions, preprocess_input
label = decode_predictions(yhat2)
label
# Out:
# [[('n03314780', 'face_powder', 0.23239876),
#   ('n04548362', 'wallet', 0.104150474),
#   ('n03291819', 'envelope', 0.0872267),
#   ('n03908618', 'pencil_box', 0.080018915),
#   ('n04116512', 'rubber_eraser', 0.064814515)]]
